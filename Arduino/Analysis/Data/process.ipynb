# %%
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

for i in glob('*.CSV'):
    df = pd.read_csv(i)
    plot = df.plot.line(title=i, x="time", y=" sensor_val")
    plt.savefig(i+".png", dpi=300)
